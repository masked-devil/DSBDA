# %%
import pandas as pd

# %%
a=pd.read_csv(r"C:\Users\91935\Downloads\airquality.csv")

# %%
#data cleaning

# %%
a.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# Humidity      72
# dtype: int64

# %%
a=a.drop(columns=['Unnamed: 0'])

# %%
a['Ozone']=a['Ozone'].fillna(a['Ozone'].mean())
a['Solar.R']=a['Solar.R'].fillna(a['Solar.R'].mean())
a['Humidity']=a['Humidity'].fillna(a['Humidity'].mode()[0])

# %%
a
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     high
# 1    36.00000  118.000000   8.0    72      5    2   medium
# 2    12.00000  149.000000  12.6    74      5    3      low
# 3    18.00000  313.000000  11.5    62      5    4   medium
# 4    42.12931  185.931507  14.3    56      5    5      low
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26      low
# 149  42.12931  145.000000  13.2    77      9   27      low
# 150  14.00000  191.000000  14.3    75      9   28      low
# 151  18.00000  131.000000   8.0    76      9   29      low
# 152  20.00000  223.000000  11.5    68      9   30      low
#
# [153 rows x 7 columns]

# %%
a.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    0
# dtype: int64

# %%
#label encoding

# %%
from sklearn import preprocessing
a['Humidity']=preprocessing.LabelEncoder().fit_transform(a['Humidity'])

# %%
a
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day  Humidity
# 0    41.00000  190.000000   7.4    67      5    1         1
# 1    36.00000  118.000000   8.0    72      5    2         3
# 2    12.00000  149.000000  12.6    74      5    3         2
# 3    18.00000  313.000000  11.5    62      5    4         3
# 4    42.12931  185.931507  14.3    56      5    5         2
# ..        ...         ...   ...   ...    ...  ...       ...
# 148  30.00000  193.000000   6.9    70      9   26         2
# 149  42.12931  145.000000  13.2    77      9   27         2
# 150  14.00000  191.000000  14.3    75      9   28         2
# 151  18.00000  131.000000   8.0    76      9   29         2
# 152  20.00000  223.000000  11.5    68      9   30         2
#
# [153 rows x 7 columns]

# %%
#data visualization

# %%
import matplotlib.pyplot as plt

# %%
#pie chart

# %%
labels=['Ozone','Solar.R','Wind','Temperature']
sizes=[a['Ozone'].mean(),a['Solar.R'].mean(),a['Wind'].mean(),a['Temp'].mean()]
colors=['red','pink','yellow','green']
explode=(0.1,0,0,0)
plt.pie(sizes,explode,labels,colors,autopct='%1.1f%%',shadow=True)
plt.title('Average data')
plt.show()

# %%
#bar chart

# %%
import numpy as np
h=a.iloc[1:21,3]
y_pos=np.arange(len(h))
v=range(1,21)
plt.bar(y_pos,h)
plt.xticks(y_pos,v)
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title('Temperatures for 1st to 20th May')
plt.show()

# %%
#line graph

# %%
h=a.iloc[1:16,0]
v=a.iloc[1:16,2]
plt.plot(h,label="Ozone",marker='*',linestyle='dotted')
plt.plot(v,label="Wind",marker='o',linestyle='dashed')
plt.legend()
plt.ylim(0,60)
plt.title("Ozone and Wind chart for 1st to 15th May")
plt.ylabel("Value Range")
plt.xlabel("Days")
plt.show()

# %%
#histogram

# %%
h=a.iloc[:,3]
plt.hist(h,bins='auto')
plt.title("Histogram for Temperatures")
plt.xlabel("No. of values")
plt.ylabel("Temperature")
plt.show()

# %%
#box plot

# %%
a.boxplot(by="Month",column=['Temp'],grid=False)
# Out:
# <Axes: title={'center': 'Temp'}, xlabel='Month'>

# %%
#pair plot

# %%
import seaborn as sb
sb.set(style='dark')
sb.pairplot(a)
# Out:
# C:\Users\91935\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#scatter plot

# %%
wind=a.iloc[:,2]
temperature=a.iloc[:,3]
plt.scatter(wind,temperature,color='black')
plt.xlabel("Wind")
plt.ylabel("Temperature")
plt.savefig("scatter_plot.png")
plt.title("Wind vs Temperature")
plt.show()

# %%
#heatmap

# %%
sb.heatmap(a)
# Out:
# <Axes: >
